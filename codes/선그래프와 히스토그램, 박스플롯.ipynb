# %%
import pandas as pd
import numpy as np
import pydataset
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='AppleGothic') 			#
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# %% [markdown]
# #### 선그래프
# 시계열을 볼 때
# x = 시간축(기간축, 날짜축)
# y = 값

# %%
economics = pydataset.data('economics')

# %%
economics
# Out:
#            date     pce     pop  psavert  uempmed  unemploy
# 1    1967-06-30   507.8  198712      9.8      4.5      2944
# 2    1967-07-31   510.9  198911      9.8      4.7      2945
# 3    1967-08-31   516.7  199113      9.0      4.6      2958
# 4    1967-09-30   513.3  199311      9.8      4.9      3143
# 5    1967-10-31   518.5  199498      9.7      4.7      3066
# ..          ...     ...     ...      ...      ...       ...
# 474  2006-11-30  9478.5  301070     -1.1      7.3      6849
# 475  2006-12-31  9540.3  301296     -0.9      8.1      7017
# 476  2007-01-31  9610.6  301481     -1.0      8.1      6865
# 477  2007-02-28  9653.0  301684     -0.7      8.5      6724
# 478  2007-03-31  9705.0  301913     -1.3      8.7      6801
#
# [478 rows x 6 columns]

# %%
sns.lineplot(data = economics, x = 'date', y = 'unemploy')
# Out:
# <AxesSubplot:xlabel='date', ylabel='unemploy'>

# %%
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 42.3+ KB

# %%
economics['date2'] = pd.to_datetime(economics['date'])

economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    int64
#  6   date2     478 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 46.0+ KB

# %%
economics[['date', 'date2']]
# Out:
#            date      date2
# 1    1967-06-30 1967-06-30
# 2    1967-07-31 1967-07-31
# 3    1967-08-31 1967-08-31
# 4    1967-09-30 1967-09-30
# 5    1967-10-31 1967-10-31
# ..          ...        ...
# 474  2006-11-30 2006-11-30
# 475  2006-12-31 2006-12-31
# 476  2007-01-31 2007-01-31
# 477  2007-02-28 2007-02-28
# 478  2007-03-31 2007-03-31
#
# [478 rows x 2 columns]

# %%
economics.date2.dt.year
# Out:
# 1      1967
# 2      1967
# 3      1967
# 4      1967
# 5      1967
#        ...
# 474    2006
# 475    2006
# 476    2007
# 477    2007
# 478    2007
# Name: date2, Length: 478, dtype: int64

# %%
economics.date2.dt.month
# Out:
# 1       6
# 2       7
# 3       8
# 4       9
# 5      10
#        ..
# 474    11
# 475    12
# 476     1
# 477     2
# 478     3
# Name: date2, Length: 478, dtype: int64

# %%
economics.date2.dt.day
# Out:
# 1      30
# 2      31
# 3      31
# 4      30
# 5      31
#        ..
# 474    30
# 475    31
# 476    31
# 477    28
# 478    31
# Name: date2, Length: 478, dtype: int64

# %%
economics['year'] = economics.date2.dt.year

# %%
economics
# Out:
#            date     pce     pop  psavert  uempmed  unemploy      date2  year
# 1    1967-06-30   507.8  198712      9.8      4.5      2944 1967-06-30  1967
# 2    1967-07-31   510.9  198911      9.8      4.7      2945 1967-07-31  1967
# 3    1967-08-31   516.7  199113      9.0      4.6      2958 1967-08-31  1967
# 4    1967-09-30   513.3  199311      9.8      4.9      3143 1967-09-30  1967
# 5    1967-10-31   518.5  199498      9.7      4.7      3066 1967-10-31  1967
# ..          ...     ...     ...      ...      ...       ...        ...   ...
# 474  2006-11-30  9478.5  301070     -1.1      7.3      6849 2006-11-30  2006
# 475  2006-12-31  9540.3  301296     -0.9      8.1      7017 2006-12-31  2006
# 476  2007-01-31  9610.6  301481     -1.0      8.1      6865 2007-01-31  2007
# 477  2007-02-28  9653.0  301684     -0.7      8.5      6724 2007-02-28  2007
# 478  2007-03-31  9705.0  301913     -1.3      8.7      6801 2007-03-31  2007
#
# [478 rows x 8 columns]

# %%
economics['month'] = economics.date2.dt.month
economics['day'] = economics.date2.dt.day

# %%
economics
# Out:
#            date     pce     pop  psavert  uempmed  unemploy      date2  year  \
# 1    1967-06-30   507.8  198712      9.8      4.5      2944 1967-06-30  1967
# 2    1967-07-31   510.9  198911      9.8      4.7      2945 1967-07-31  1967
# 3    1967-08-31   516.7  199113      9.0      4.6      2958 1967-08-31  1967
# 4    1967-09-30   513.3  199311      9.8      4.9      3143 1967-09-30  1967
# 5    1967-10-31   518.5  199498      9.7      4.7      3066 1967-10-31  1967
# ..          ...     ...     ...      ...      ...       ...        ...   ...
# 474  2006-11-30  9478.5  301070     -1.1      7.3      6849 2006-11-30  2006
# 475  2006-12-31  9540.3  301296     -0.9      8.1      7017 2006-12-31  2006
# 476  2007-01-31  9610.6  301481     -1.0      8.1      6865 2007-01-31  2007
# 477  2007-02-28  9653.0  301684     -0.7      8.5      6724 2007-02-28  2007
# 478  2007-03-31  9705.0  301913     -1.3      8.7      6801 2007-03-31  2007
#
#      month  day
# 1        6   30
# ...

# %%
sns.lineplot(data = economics, x = 'year', y = 'unemploy')
# Out:
# <AxesSubplot:xlabel='year', ylabel='unemploy'>

# %%
sns.lineplot(data = economics, x = 'year', y = 'unemploy', ci = None)
# Out:
# <AxesSubplot:xlabel='year', ylabel='unemploy'>

# %%
# p.217

# %%
mpg = pydataset.data('mpg').rename(columns={'class':'category'})

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# ### Q1
# psavert가 시간에 따라서 어떻게 변해 왔는가?
#
# ### Q2
# 2014년 월별 psavert의 변화를 그려보세요.

# %%
sns.lineplot(data = economics, x = 'date2', y = 'psavert', ci = None)
# Out:
# <AxesSubplot:xlabel='date2', ylabel='psavert'>

# %%
sns.lineplot(data = economics.query('year == 2005'), x = 'month', y = 'psavert')
# Out:
# <AxesSubplot:xlabel='month', ylabel='psavert'>

# %% [markdown]
# ### 히스토그램
#
# 연속형 변수

# %%
import pandas as pd
import numpy as np
import pydataset
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='AppleGothic') 			#
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# %%
iris = pydataset.data('iris')

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %%
iris['Sepal.Length'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data = iris, x = 'Sepal.Length')
# Out:
# <AxesSubplot:xlabel='Sepal.Length', ylabel='Count'>

# %%
sns.histplot(data = iris, x = 'Sepal.Width')
# Out:
# <AxesSubplot:xlabel='Sepal.Width', ylabel='Count'>

# %%
sns.histplot(data = iris)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data = iris, x = 'Sepal.Width', binwidth=0.15)
# Out:
# <AxesSubplot:xlabel='Sepal.Width', ylabel='Count'>

# %% [markdown]
# ### 상자그림
# boxplot

# %%
sns.boxplot(data = mpg, x = 'drv', y = 'hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='hwy'>

# %%
mpg = pydataset.data('mpg').rename(columns={'class':'category'})
sns.boxplot(data = mpg, x = 'category', y = 'cty')
# Out:
# <AxesSubplot:xlabel='category', ylabel='cty'>
