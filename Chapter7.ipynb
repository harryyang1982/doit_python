# %% [markdown]
# <a href="https://colab.research.google.com/github/harryyang1982/doit_python/blob/main/Chapter7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'sex': ['M', 'F', np.nan, 'M', 'F'],
                   'score': [5, 4, 3, 4, np.nan]})

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df['score'] + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# 4    NaN
# Name: score, dtype: float64

# %%
pd.isna(df)
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
pd.isna(df).sum()
# Out:
# sex      1
# score    1
# dtype: int64

# %%
df.dropna(subset = ['score'])
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss = df.dropna(subset = ['score'])
df_nomiss['score'] + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# Name: score, dtype: float64

# %%
df_nomiss = df.dropna(subset = ['score', 'sex'])
df_nomiss
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df_nomiss2 = df.dropna()
df_nomiss2
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df.score.mean()
# Out:
# 4.0

# %%
df.score.sum()
# Out:
# 16.0

# %%
df.groupby('sex').agg(mean_score = ('score', 'mean'),
                      sum_score = ('score', 'sum'))
# Out:
#      mean_score  sum_score
# sex
# F           4.0        4.0
# M           4.5        9.0

# %%
exam = pd.read_csv('https://github.com/youngwoos/Doit_Python/raw/main/Data/exam.csv')

# %%
exam.loc[[2, 7, 14], ['math']] = np.nan
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam.math.mean()
# Out:
# 55.23529411764706

# %%
exam['math'] = exam['math'].fillna(55)
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1  55.0       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2  55.0       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4  55.0       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam['math'].isna().sum()
# Out:
# 0

# %%
mpg = pd.read_csv('https://github.com/tidyverse/ggplot2/raw/main/data-raw/mpg.csv').rename(columns={'class':'category'})

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg2 = mpg.copy()
mpg2.loc[[64, 123, 130, 152, 211], 'hwy'] = np.nan

# %%
mpg2
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty   hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18  29.0  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21  29.0  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20  31.0  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21  30.0  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16  26.0  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...   ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19  28.0  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21  29.0  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16  26.0  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18  26.0  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17  26.0  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg2.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             5
# fl              0
# category        0
# dtype: int64

# %%
mpg2.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#       mean_hwy
# drv
# 4    19.242424
# f    28.200000
# r    21.000000

# %%
mpg2[['hwy', 'drv']].isna().sum()
# Out:
# hwy    5
# drv    0
# dtype: int64

# %%
mpg_nomiss = mpg2.dropna()

# %%
mpg_nomiss.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#       mean_hwy
# drv
# 4    19.242424
# f    28.200000
# r    21.000000

# %% [markdown]
# ## 7-2 이상치 제거

# %%
df = pd.DataFrame({'sex': [1, 2, 1, 3, 2, 1],
                   'score': [5, 4, 3, 4, 2, 6]})

# %%
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'].value_counts().sort_index()
# Out:
# 1    3
# 2    2
# 3    1
# Name: sex, dtype: int64

# %%
df['score'].value_counts().sort_index()
# Out:
# 2    1
# 3    1
# 4    2
# 5    1
# 6    1
# Name: score, dtype: int64

# %%
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])
df['score'] = np.where(df['score'] <= 5, df['score'], np.nan)
df
# Out:
#    sex  score
# 0  1.0    5.0
# 1  2.0    4.0
# 2  1.0    3.0
# 3  NaN    4.0
# 4  2.0    2.0
# 5  1.0    NaN

# %%
df.dropna(subset = ['sex', 'score'])\
.groupby('sex')\
.agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df = pd.DataFrame({'x1': [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 'a', np.nan)

# %%
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  nan
# 3   2  nan

# %%
df['x2'] = np.where(df['x1'] == 1, 'a', 'etc')
df['x2'] = df['x2'].replace('etc', np.nan)
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  NaN
# 3   2  NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
import seaborn as sns 
sns.boxplot(y = 'hwy', data = mpg)

# %%
pct25 = mpg['hwy'].quantile(.25)
pct75 = mpg['hwy'].quantile(.75)
print(pct25, pct75)
# Out:
# 18.0 27.0

# %%
iqr = pct75 - pct25

# %%
iqr
# Out:
# 9.0

# %%
pct25 - 1.5 * iqr
# Out:
# 4.5

# %%
pct75 + 1.5 * iqr
# Out:
# 40.5

# %%
mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5),
                      np.nan, mpg['hwy'])

# %%
mpg['hwy'].isna().sum()
# Out:
# 3

# %%
mpg.dropna(subset = ['hwy'])\
.groupby('drv')\
.agg(mean_hwy = ('hwy', 'mean'))
# Out:
#       mean_hwy
# drv
# 4    19.174757
# f    27.728155
# r    21.000000

# %%
mpg = pd.read_csv('https://github.com/tidyverse/ggplot2/raw/main/data-raw/mpg.csv').rename(columns={'class':'category'})

# %%
mpg.loc[[9, 13, 57, 92], 'drv'] = 'k'
mpg.loc[[28, 42, 128, 202], 'cty'] = [3, 4, 39, 42]

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.drv.value_counts()
# Out:
# f    106
# 4    100
# r     24
# k      4
# Name: drv, dtype: int64

# %%
mpg_noerror = mpg.copy()
mpg_noerror['drv'] = mpg.drv.replace('k', np.nan)

# %%
mpg_noerror
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
p25 = mpg.cty.quantile(.25)
p75 = mpg.cty.quantile(.75)
iqr = p75 - p25

# %%
p25 - iqr * 1.5
# Out:
# 6.5

# %%
p75 + iqr * 1.5
# Out:
# 26.5

# %%
mpg_noerror
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg_noerror['cty'] = np.where((mpg_noerror['cty'] < 6.5) | (mpg_noerror['cty'] > 26.5), 
                              np.nan, mpg_noerror['cty'])

# %%
mpg_noerror = mpg_noerror.dropna()

# %%
sns.boxplot(y = 'cty', data = mpg_noerror)

# %%
mpg_noerror.groupby('drv').agg(cty_mean = ('cty', 'mean'))
# Out:
#       cty_mean
# drv
# 4    14.247423
# f    19.470000
# r    13.958333
